# %% [markdown]
# ## Loading the Data

# %%
# Load Training Data

import pandas as pd

training_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

print('Size of Training Data: ',training_data.shape)
print('Size of Test Data: ', test_data.shape)
# Out:
# Size of Training Data:  (1460, 81)
# Size of Test Data:  (1459, 80)

# %% [markdown]
# ## Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as st
from sklearn import ensemble, tree, linear_model
import missingno as msno

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# The describe method can be used to get various statistics that exclude NaN values.

# %%
training_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# Taking a look at some of the data by using the head() and tail() functions in Pandas.

# %%
training_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
training_data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1455         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1456         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1459         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Examining numerical features in the data set. We do this by looking at the object type within the dataframe.

# %%
num_features = training_data.select_dtypes(include=[np.number])
num_features.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
num_features.shape
# Out:
# (1460, 38)

# %% [markdown]
# Examining categorical features in the training dataset.

# %%
cat_features = training_data.select_dtypes(include=[np.object])
cat_features.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
cat_features.shape
# Out:
# (1460, 43)

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %% [markdown]
# Visualizing missing values for a sample of 250

# %%
# If x labels are desired, also pass arguement labels=True
msno.matrix(training_data.sample(250))

# %%
msno.bar(training_data.sample(250))

# %%
msno.heatmap(training_data)

# %%
msno.dendrogram(training_data)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %% [markdown]
# ## Looking at Skewness and Kurtosis

# %%
training_data.skew(), training_data.kurt()
# Out:
# (Id                0.000000
#  MSSubClass        1.407657
#  LotFrontage       2.163569
#  LotArea          12.207688
#  OverallQual       0.216944
#  OverallCond       0.693067
#  YearBuilt        -0.613461
#  YearRemodAdd     -0.503562
#  MasVnrArea        2.669084
#  BsmtFinSF1        1.685503
#  BsmtFinSF2        4.255261
#  BsmtUnfSF         0.920268
#  TotalBsmtSF       1.524255
#  1stFlrSF          1.376757
#  2ndFlrSF          0.813030
#  LowQualFinSF      9.011341
#  GrLivArea         1.366560
#  BsmtFullBath      0.596067
#  BsmtHalfBath      4.103403
#  FullBath          0.036562
#  HalfBath          0.675897
#  BedroomAbvGr      0.211790
#  KitchenAbvGr      4.488397
#  TotRmsAbvGrd      0.676341
#  Fireplaces        0.649565
#  GarageYrBlt      -0.649415
#  GarageCars       -0.342549
#  GarageArea        0.179981
#  WoodDeckSF        1.541376
#  OpenPorchSF       2.364342
#  EnclosedPorch     3.089872
#  3SsnPorch        10.304342
#  ScreenPorch       4.122214
# ...

# %%
y = training_data['SalePrice']
plt.figure(1); plt.title('Johnson SU')
sns.distplot(y, kde=False, fit=st.johnsonsu)
plt.figure(2); plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)
plt.figure(3); plt.title('Log Normal')
sns.distplot(y, kde=False, fit=st.lognorm)

# %% [markdown]
# From the graphs, it is evident that this is not a normal distribution. We will have to transform the data before performing a regression. The best fit is unbounded Johnson distribution.

# %%
sns.distplot(training_data.skew(),color='blue',axlabel='Skewness')

# %%
plt.figure(figsize = (12,8))
sns.distplot(training_data.kurt(),color='r',axlabel ='Kurtosis',norm_hist= False, kde = True,rug = False)
plt.show()

# %%
plt.hist(training_data['SalePrice'],orientation = 'vertical',histtype = 'bar', color = 'blue')
plt.show()

# %%
target = np.log(training_data['SalePrice'])
target.skew
plt.hist(target,color='blue')
# Out:
# (array([  5.,  12.,  54., 184., 470., 400., 220.,  90.,  19.,   6.]),
#  array([10.46024211, 10.7676652 , 11.07508829, 11.38251138, 11.68993448,
#         11.99735757, 12.30478066, 12.61220375, 12.91962684, 13.22704994,
#         13.53447303]),
#  <a list of 10 Patch objects>)

# %%
print(target)
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
# 5       11.870600
# 6       12.634603
# 7       12.206073
# 8       11.774520
# 9       11.678440
# 10      11.771436
# 11      12.751300
# 12      11.877569
# 13      12.540758
# 14      11.964001
# 15      11.790557
# 16      11.911702
# 17      11.407565
# 18      11.976659
# 19      11.842229
# 20      12.692503
# 21      11.845103
# 22      12.345835
# 23      11.774520
# 24      11.944708
# 25      12.454104
# 26      11.811547
# 27      12.631340
# 28      12.242887
# 29      11.134589
#           ...
# 1430    12.165980
# 1431    11.875831
# 1432    11.074421
# 1433    12.136187
# 1434    11.982929
# 1435    12.066811
# 1436    11.699405
# 1437    12.885671
# 1438    11.916389
# 1439    12.190959
# 1440    12.160029
# 1441    11.913713
# 1442    12.644328
# 1443    11.703546
# 1444    12.098487
# 1445    11.767568
# 1446    11.969717
# 1447    12.388394
# 1448    11.626254
# ...

# %%
correlation = num_features.corr()
print(correlation['SalePrice'].sort_values(ascending = False),'\n')
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %% [markdown]
# # For farther exploration we use the following:
# * Correlation Heat Map
# * Zoomed Heat Map
# * Pair Plot
# * Scatter Plot

# %% [markdown]
# ## Corelation Heat Map

# %%
f, ax = plt.subplots(figsize = (14,12))

plt.title('Correlation of Numeric Features with Sale Price', y=1, size=16)

sns.heatmap(correlation,square=True,vmax=0.8)

# %% [markdown]
# There are two distinct squares. One referring to 'TotalBsmtSF' and '1stFlrSF'. Another one referring to the 'GarageX' variable.
# * Notice 'GrLivArea', 'TotalBsmtSF', and 'OverallQual' are corellated to SalePrice

# %% [markdown]
# ## Zoomed HeatMap

# %%
k = 11
cols = correlation.nlargest(k,'SalePrice')['SalePrice'].index
print(cols)
cm = np.corrcoef(training_data[cols].values.T)
f, ax = plt.subplots(figsize = (14, 12))
sns.heatmap(cm, vmax=.8, linewidths=0.01, square=True, annot=True, cmap='viridis',
           linecolor='white',xticklabels = cols.values, annot_kws = {'size':12},yticklabels = cols.values)
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
#        'YearRemodAdd'],
#       dtype='object')
